# %% [markdown]
# **굵은 텍스트**# 자료 1
#
# Machine Learning / Deep Learning의 코드는 대부분 Python을 기반으로 합니다.
#
# 본 파일은 Python을 사용하는 것에 아직 미숙함을 가지고 계실 분들을 위해 만들어본 자료입니다.
#
# 본 자료는 https://wikidocs.net/1 를 참고하여 만들었습니다.

# %% [markdown]
# # Print

# %%
print ("Hello world")
# Out:
# Hello world

# %%
print('Hello, this is {}'.format('Aaron'))
# Out:
# Hello, this is Aaron

# %%
print('Hello, this is {} and I\'m {} years old'.format('Aaron', 30))
# Out:
# Hello, this is Aaron and I'm 30 years old

# %% [markdown]
# ----

# %% [markdown]
# # Input

# %%
a = input("Tell me anthing you want: ")
# Out:
# Tell me anthing you want: 치킨

# %%
print(a)
# Out:
# 치킨

# %% [markdown]
# -----

# %% [markdown]
# # Type
# ## int / float / str / bool
# - 변수 선언이 필요 없다는 것이 C/Java와 가장 큰 차이점

# %%
a = 10
print (a, type(a))

a = 10.0
print (a, type(a))

a = 'hi'
print (a, type(a))

a = True
print (a, type(a))
# Out:
# 10 <class 'int'>
# 10.0 <class 'float'>
# hi <class 'str'>
# True <class 'bool'>

# %% [markdown]
# - 정수 (int) 및 실수 (float)

# %%
a,b = 3,4

print (a+b)
print (a-b)
print (a*b)
print (a/b)
print ()

print (a**b)
print (a%b)
print (a//b)
# Out:
# 7
# -1
# 12
# 0.75
#
# 81
# 3
# 0

# %% [markdown]
# - 문자열 (str)

# %%
a = 'hi'
b = 'hello'
c = a + ' ' + b
d = c.replace('h', 'p')
# print(c) ctrl + /
e = (d+' ')*3

print (a)
print (b)
print (c)
print (d)
print (e)
print (e.count('e'))
print(e.find('e'))
print (e.split())
# Out:
# hi
# hello
# hi hello
# pi pello
# pi pello pi pello pi pello
# 3
# 4
# ['pi', 'pello', 'pi', 'pello', 'pi', 'pello']

# %% [markdown]
# - 논리형(bool)

# %%
# shift + enter
print (True and True)
print (True and False)
print (False and True)
print (False and False)
print ("----------")
print (True or True)
print (True or False)
print (False or True)
print (False or False)
# Out:
# True
# False
# False
# False
# ----------
# True
# True
# True
# False

# %% [markdown]
# - list

# %%
lst1 = [1 , 7, 5, 3, 2]
print ('first element: {}'.format(lst1[0]))
print ('last element: {}'.format(lst1[len(lst1)-1]))
print ('last element: {}'.format(lst1[-1]))
print ('first to third elements: {}'.format(lst1[0:3]))
print ('sorted lst: {}\n'.format(sorted(lst1)))

print (lst1)
lst1.append(4)
print (lst1)
print('-------')

lst1.insert(3, 10)
print (lst1)
print('-------')


lst1.append([5,8]) # [1,7,5,10,3,2,4, [5,8]]
print (lst1)
print('-------')


lst1.remove(5) # value
print (lst1)
print('-------')


lst1.pop(5) # 5번쨰 index
print (lst1)
print ()
print('-------')

lst1 = [1, 7 , 5, 3, 2]
lst2 = [5, 8]
print (lst1+lst2)
print (lst2*4)
print ()

print (max(lst1))
print (min(lst1))

train_x = [[2,3,4], [3,2,1], [5,4,3], [3,2,4], [5,3,2]]
train_y = [0,0,1,1,0]
train_dataset = list(zip(train_x, train_y))
print (train_dataset)
# Out:
# first element: 1
# last element: 2
# last element: 2
# first to third elements: [1, 7, 5]
# sorted lst: [1, 2, 3, 5, 7]
#
# [1, 7, 5, 3, 2]
# [1, 7, 5, 3, 2, 4]
# -------
# [1, 7, 5, 10, 3, 2, 4]
# -------
# [1, 7, 5, 10, 3, 2, 4, [5, 8]]
# -------
# [1, 7, 10, 3, 2, 4, [5, 8]]
# -------
# [1, 7, 10, 3, 2, [5, 8]]
#
# -------
# [1, 7, 5, 3, 2, 5, 8]
# [5, 8, 5, 8, 5, 8, 5, 8]
#
# 7
# 1
# [([2, 3, 4], 0), ([3, 2, 1], 0), ([5, 4, 3], 1), ([3, 2, 4], 1), ([5, 3, 2], 0)]

# %% [markdown]
# - set

# %%
lst1 = [3,5] * 3
lst2 = [5,7] * 2
set1 = set(lst1)
set2 = set(lst2)
print (set1, set2)
print ()

print (set1.union(set2))
print (set1.intersection(set2))
print (set1.difference(set2))
print (set2.difference(set1))
print ()

print (set1| set2)
print (set1& set2)
print (set1 - set2)
print (set2 - set1)
# Out:
# {3, 5} {5, 7}
#
# {3, 5, 7}
# {5}
# {3}
# {7}
#
# {3, 5, 7}
# {5}
# {3}
# {7}

# %% [markdown]
# - tuple: 리스트는 가변적(mutable; 변경 가능)이지만 튜플은 불변적(immutable; 변경 불가)임

# %%
tpl = (1, 7, 5, 3, 2)
print ('first element: {}'.format(tpl[0]))
print ('last element: {}'.format(tpl[len(tpl)-1]))
print ('last element: {}'.format(tpl[-1]))
print ('first to third elements: {}'.format(tpl[:3]))
print ('sorted lst: {}\n'.format(sorted(tpl)))
# Out:
# first element: 1
# last element: 2
# last element: 2
# first to third elements: (1, 7, 5)
# sorted lst: [1, 2, 3, 5, 7]

# %% [markdown]
# - dictionary

# %%
dic = {'H': 1, 'He': 2, 'Li': 3, 'Be': 4} #key - value pair
print ('The atomic number of H: {}'.format(dic['H']))
print ('The atomic number of Be: {}'.format(dic['Be']))
dic['B'] = 5

print ()
print (dic.items())
print (dic.keys())
print (dic.values())
# Out:
# The atomic number of H: 1
# The atomic number of Be: 4
#
# dict_items([('H', 1), ('He', 2), ('Li', 3), ('Be', 4), ('B', 5)])
# dict_keys(['H', 'He', 'Li', 'Be', 'B'])
# dict_values([1, 2, 3, 4, 5])

# %% [markdown]
# - if / elif / else

# %%
import random

# %%
val = random.randint(1, 50)
if val%3 ==0:
    print ('{} is 3n form'.format(val))
elif val%3 ==1:
    print ('{} is 3n+1 form'.format(val))
else:
    print ('{} is 3n+2 form'.format(val))
# Out:
# 3 is 3n form

# %% [markdown]
# - assert: 조건을 만족하지 않는 경우 AssertionError()를 냄

# %%
a=3
b=3
assert a==b

# %%
a=3
b=5
assert a==b
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-20-69b82f38a025> in <module>()
#       1 a=3
#       2 b=5
# ----> 3 assert a==b
#
# AssertionError:

# %% [markdown]
# - for (list)

# %%
import matplotlib.pyplot as plt 

plt.plot([1, 2, 3, 4], [1, 4, 9, 16], 'o')

# plt.axis([0, 6, 0, 20]) 
plt.show()

# %%
lst = [1, 7, 5, 3, 2]
for val in lst: print (val)
# Out:
# 1
# 7
# 5
# 3
# 2

# %%
lst = [1, 7, 5, 3, 2]
for idx in range(len(lst)): # [0,1,2,3,4]
    print (idx, lst[idx])
# Out:
# 0 1
# 1 7
# 2 5
# 3 3
# 4 2

# %%
lst = [1, 7, 5, 3, 2]
for idx, val in enumerate(lst):
    print (idx, val)
# Out:
# 0 1
# 1 7
# 2 5
# 3 3
# 4 2

# %% [markdown]
# - for (dictionary)

# %%
search_val = 3


for k, v in dic.items(): # [(key1, value1), (key2, value2), ...]
    if v == search_val:
        print (k, v)
# Out:
# Li 3

# %% [markdown]
# - list comprehension: (조건문) + 반복문 => list

# %%
company1 = [['삼성', 1000000, '갤럭시노트'], ['애플', 1200000, '아이폰'], ['엘지', 900000, '윙']]
print(pd.DataFrame(company1)) 


df1 = pd.DataFrame(company1) 
print(df1)

df1.columns = ['회사명', '가격', '제품명']
print(df1)
# Out:
#     0        1      2
# 0  삼성  1000000  갤럭시노트
# 1  애플  1200000    아이폰
# 2  엘지   900000      윙
#     0        1      2
# 0  삼성  1000000  갤럭시노트
# 1  애플  1200000    아이폰
# 2  엘지   900000      윙
#   회사명       가격    제품명
# 0  삼성  1000000  갤럭시노트
# 1  애플  1200000    아이폰
# 2  엘지   900000      윙

# %%
lst = [1, 2, 'A', False, 3]
new_lst = []
for i in lst:
    if type(i) == int:
        new_lst.append(i*i)
print(new_lst)
# Out:
# [1, 4, 9]

# %%
lst = [1, 2, 'A', False, 3]
new_lst = [i*i for i in lst if type(i)==int]
print (new_lst)
# Out:
# [1, 4, 9]

# %%
result = [x*y for x in range(2,4) \
         for y in range(1,10)]
print (result)
# Out:
# [2, 4, 6, 8, 10, 12, 14, 16, 18, 3, 6, 9, 12, 15, 18, 21, 24, 27]

# %% [markdown]
# # 함수
# - Basic

# %%
def calc(x, y, op='+'):
    if op == '+':
        z = x + y
    elif op == '-':
        z = x - y
    elif op == '*':
        z = x * y
    elif op == '/':
        z = x / y
    else:
        z = 'This operation is not defined'
    
    return z

# %%
print (calc(5,5,'/'))
# Out:
# 1.0

# %%
def return_add_minus(x,y):
    return x+y, x-y

# %%
plus, minus = return_add_minus(5,3)
print (plus)
print (minus)
# Out:
# 8
# 2

# %% [markdown]
# - Mutable parameters: 파라미터의 수가 가변적인 경우
#     1. Mutable parameters를 tuple로 받는 경우

# %%
def fn_tpl(x, y, *args):
    print (args)
    print ()
    for arg in args:
        print (arg)

# %%
fn_tpl(1, 2, 3, [4, 5], 'Hello', ['Hi', 'Hello'])
# Out:
# (3, [4, 5], 'Hello', ['Hi', 'Hello'])
#
# 3
# [4, 5]
# Hello
# ['Hi', 'Hello']

# %% [markdown]
# 2. Mutable parameters를 dictionary로 받는 경우

# %%
def fn_dict(x, y, **kwargs):
    print (kwargs)
    print ()
    for k, v in kwargs.items():
        print ('{}: {}'.format(k, v))

# %%
fn_dict(1, 2, z1=3, z2=[4, 5], z3='Hello', z4=['Hi', 'Hello'])
# Out:
# {'z1': 3, 'z2': [4, 5], 'z3': 'Hello', 'z4': ['Hi', 'Hello']}
#
# z1: 3
# z2: [4, 5]
# z3: Hello
# z4: ['Hi', 'Hello']

# %% [markdown]
# - Lambda: 간단한 함수를 한 줄만으로 만듦 => lambda parameters: function의 형태

# %%
lmd = lambda x,y: x + y
print (lmd(10,20))
# Out:
# 30

# %% [markdown]
# 1. map (함수, 리스트)

# %%
lmd1 = lambda x: x ** 2
list(map(lmd1, range(5)))
# Out:
# [0, 1, 4, 9, 16]

# %% [markdown]
# 2. filter (함수, 리스트)

# %%
lmd2 = lambda x: x < 5
list(filter(lmd2, range(10)))
# Out:
# [0, 1, 2, 3, 4]

# %% [markdown]
# # 클래스
# - 클래스 / 객체 / 생성자 / 메쏘드

# %%
class Cls:
    def __init__(self):
        self.val = 0
        
    def view(self):
        print (self.val)

# %%
f = Cls()
f.view()
# Out:
# 0

# %%
class Cls:
    def __init__(self, val):
        self.val = val
        
    def view(self):
        print (self.val)

# %%
f1 = Cls(3)
f1.view()

f2 = Cls('Hi')
f2.view()
# Out:
# 3
# Hi

# %%
class Cls:
    def __init__(self, x, y):
        self.x = x
        self.y = y
        
    def add(self):
        print (self.x + self.y)
        
    def sub(self):
        print (self.x - self.y)
        
    def mul(self):
        print (self.x * self.y)
        
    def div(self):
        print (self.x / self.y)

# %%
f = Cls(5,3)
f.add()
f.sub()
f.mul()
f.div()
# Out:
# 8
# 2
# 15
# 1.6666666666666667

# %%
class Cls1:
    def __init__(self, cls1_val):
        self.cls1_val = cls1_val
        
    def view(self):
        print (self.cls1_val)
        
class Cls2(Cls1):
    def __init__(self, cls1_val, cls2_val):
        super(Cls2, self).__init__(cls1_val)
        self.cls2_val = cls2_val
    
    def view(self):
        print(self.cls1_val, self.cls2_val)

# %%
f1 = Cls1(3)
f1.view()
f2 = Cls2(3, 5)
f2.view()
# Out:
# 3
# 3 5

# %% [markdown]
# - real pytorch form

# %%
import torch.nn as nn

# %%
class Net(nn.Module):
    def __init__(self):
        super(Net, self).__init__()
        
    def forward(self, x):
        return x

model = Net()

# %% [markdown]
# # 파일 입출력
# - 입력: 2가지의 방법 존재

# %%
fp = open('text.txt', 'r')
txt = fp.read()
print(txt)
fp.close()
# Out:
# hello
# this is taehyeon

# %%
with open('text.txt', 'r') as fp:
    print (fp.read())
# Out:
# hello
# this is taehyeon

# %% [markdown]
# - 출력: 2가지의 방법 존재

# %%
fp = open('text.txt', 'w')
txt = 'hello\nthis is taehyeon'
fp.write(txt)
fp.close()

# %%
with open('text.txt', 'w') as fp:
    txt = 'hello\nthis is taehyeon'
    fp.write(txt)
