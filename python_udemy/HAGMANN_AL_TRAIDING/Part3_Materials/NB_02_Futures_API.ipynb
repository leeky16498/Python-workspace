# %% [markdown]
# # Implementation - Futures Testnet API

# %% [markdown]
# __Insert your Futures Testnet Credentials here__:

# %%
api_key = "c1157b29b996acc5b808f5e2a3618ec3f927c12d55d639cf386d1b633139a4c6"
secret_key = "0d4806c1bd203f7291bf9d0c7eb2ff99baa7a12051797a2233d77c8e7811f50d"

# %% [markdown]
# ## Introduction to the Futures Testnet API

# %% [markdown]
# Find more information on the Futures API here:

# %% [markdown]
# https://binance-docs.github.io/apidocs/futures/en/#change-log

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com", testnet = True) # Testnet!!!

# %% [markdown]
# __Simple Rule:__ <br>
# - Use your __Testnet Credentials with testnet = True__ and your __"Real Account" Credentials with testnet = False__ (default)

# %%
client

# %% [markdown]
# __USD-margined Account__

# %%
client.futures_account() # Account details
# Out:
# {'feeTier': 0,
#  'canTrade': True,
#  'canDeposit': True,
#  'canWithdraw': True,
#  'updateTime': 0,
#  'totalInitialMargin': '2.11740399',
#  'totalMaintMargin': '0.21174039',
#  'totalWalletBalance': '2967.16829752',
#  'totalUnrealizedProfit': '0.39836005',
#  'totalMarginBalance': '2967.56665757',
#  'totalPositionInitialMargin': '2.11740399',
#  'totalOpenOrderInitialMargin': '0.00000000',
#  'totalCrossWalletBalance': '2967.16829752',
#  'totalCrossUnPnl': '0.39836005',
#  'availableBalance': '2965.08539353',
#  'maxWithdrawAmount': '2965.44925358',
#  'assets': [{'asset': 'BNB',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0},
#   {'asset': 'USDT',
#    'walletBalance': '2967.16829752',
#    'unrealizedProfit': '0.39836005',
#    'marginBalance': '2967.56665757',
#    'maintMargin': '0.21174039',
#    'initialMargin': '2.11740399',
#    'positionInitialMargin': '2.11740399',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '2965.44925358',
#    'crossWalletBalance': '2967.16829752',
#    'crossUnPnl': '0.39836005',
#    'availableBalance': '2965.08539353',
#    'marginAvailable': True,
#    'updateTime': 1655370483296},
#   {'asset': 'BUSD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000',
#    'marginAvailable': True,
#    'updateTime': 0}],
#  'positions': [{'symbol': 'RAYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'API3USDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SUSHIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CVCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FTMBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '5000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HOTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRXBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZRXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'QTUMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IOTAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WAVESUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ADAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LITUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XTZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HNTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XMRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'YFIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FTTBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '1000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALICEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ALPHAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'WOOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SFPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'REEFUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BATUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DOGEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RLCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCSTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STORJUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SNXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000XECUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DOTBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AUDIOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NEARBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XLMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'APEBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IOTXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NEOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'UNFIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SANDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DASHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KAVAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RUNEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'APEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CTKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LINKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CELRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RSRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ADABUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DGBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SKLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'RENUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LPTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'JASMYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TOMOUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MTLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LTCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DODOBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'EGLDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KSMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BNBBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ONTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'VETUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IMXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'TRBUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MANAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FLOWUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'COTIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CHRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BAKEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AVAXBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GRTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FLMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GALUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GALABUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'MASKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'EOSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OGNUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ETHUSDT_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '375000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GALBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BALUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'STMXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DENTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KNCUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SRMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ENJUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'C98USDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZENUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ATOMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.00',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NEARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SOLBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ENSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BCHUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ATAUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'IOSTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'HBARUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'LUNA2BUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
# ...
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FILUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'NKNUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'KLAYUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DEFIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'COMPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCDOMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SOLUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCUSDT',
#    'initialMargin': '2.11740399',
#    'maintMargin': '0.21174039',
#    'unrealizedProfit': '0.39836005',
#    'positionInitialMargin': '2.11740399',
#    'openOrderInitialMargin': '0',
#    'leverage': '10',
#    'isolated': False,
#    'entryPrice': '21572.4',
#    'maxNotional': '1000000',
#    'positionSide': 'BOTH',
#    'positionAmt': '-0.001',
#    'notional': '-21.17403994',
#    'isolatedWallet': '0',
#    'updateTime': 1655370483296,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OMGUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ICXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ICPBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BLZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GMTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FTMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BANDUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DOGEBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XRPBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XRPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'FTTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '100000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'SXPUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CRVUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BELUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DOTUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '250000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'XEMUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'GMTBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ONEUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': '1000LUNCBUSD',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ZILUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'AXSUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DYDXUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'OCEANUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CHZUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'ANKRUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'DUSKUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'BTCUSDT_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '375000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0.000',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'},
#   {'symbol': 'CTSIUSDT',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'entryPrice': '0.0',
#    'maxNotional': '25000',
#    'positionSide': 'BOTH',
#    'positionAmt': '0',
#    'notional': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'bidNotional': '0',
#    'askNotional': '0'}]}

# %%
pd.DataFrame(client.futures_account()["assets"])
# Out:
#   asset  walletBalance unrealizedProfit  marginBalance maintMargin  \
# 0   BNB     0.00000000       0.00000000     0.00000000  0.00000000
# 1  USDT  2967.29504200       0.00000000  2967.29504200  0.00000000
# 2  BUSD     0.00000000       0.00000000     0.00000000  0.00000000
#
#   initialMargin positionInitialMargin openOrderInitialMargin  \
# 0    0.00000000            0.00000000             0.00000000
# 1    0.00000000            0.00000000             0.00000000
# 2    0.00000000            0.00000000             0.00000000
#
#   maxWithdrawAmount crossWalletBalance  crossUnPnl availableBalance  \
# 0        0.00000000         0.00000000  0.00000000       0.00000000
# 1     2967.29504200      2967.29504200  0.00000000    2967.29504200
# 2        0.00000000         0.00000000  0.00000000       0.00000000
#
#    marginAvailable     updateTime
# 0             True              0
# 1             True  1655300781971
# 2             True              0

# %%
client.futures_account_balance() # Asset Balance details
# Out:
# [{'accountAlias': 'AuXqTimYAuSg',
#   'asset': 'BNB',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0},
#  {'accountAlias': 'AuXqTimYAuSg',
#   'asset': 'USDT',
#   'balance': '2967.29504200',
#   'withdrawAvailable': '2967.29504200',
#   'updateTime': 1655300781971},
#  {'accountAlias': 'AuXqTimYAuSg',
#   'asset': 'BUSD',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 0}]

# %%
client.futures_position_information() # current Open Positions
# Out:
# [{'symbol': 'RAYUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'API3USDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SUSHIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CVCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTSUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FTMBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'HOTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'TRXBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ZRXUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'QTUMUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'IOTAUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCBUSD',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'WAVESUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ADAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LITUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XTZUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNBUSDT',
#   'positionAmt': '0.00',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DARUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'HNTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETCUSDT',
#   'positionAmt': '0.00',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XMRUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'YFIUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FTTBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETHUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ALICEUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ALPHAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'WOOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SFPUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'REEFUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BATUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOGEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'TRXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'RLCUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCSTUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'STORJUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SNXUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': '1000XECUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOTBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AUDIOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'NEARBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XLMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'APEBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'IOTXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'NEOUSDT',
#   'positionAmt': '0.00',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'UNFIUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SANDUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DASHUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'KAVAUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'RUNEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'APEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CTKUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LINKUSDT',
#   'positionAmt': '0.00',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CELRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNXUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'OPUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'RSRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ADABUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DGBUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SKLUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'RENUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LPTUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'JASMYUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'TOMOUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'MTLUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DODOBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'EGLDUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'KSMUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNBBUSD',
#   'positionAmt': '0.00',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ONTUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'VETUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'IMXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'TRBUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'MANAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FLOWUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'COTIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CHRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BAKEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AVAXBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GRTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FLMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GALUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GALABUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'MASKUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'EOSUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'OGNUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETHUSDT_220624',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '375000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GALBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BALUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'STMXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DENTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'KNCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SRMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ENJUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'C98USDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ZENUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ATOMUSDT',
#   'positionAmt': '0.00',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'NEARUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SOLBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ENSUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BCHUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ATAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'IOSTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'HBARUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LUNA2BUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ZECUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': '1000SHIBUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'TLMBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ANTUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETHBUSD',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GALAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AAVEUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GTCUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ALGOUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LRCUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '150000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AVAXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ARPAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CELOUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ROSEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'MATICUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '150000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': '1INCHUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
# ...
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'UNIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LINAUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ARUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'RVNUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FILUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'NKNUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'KLAYUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DEFIUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'COMPUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCDOMUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SOLUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21772.17904091',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 1655300781971},
#  {'symbol': 'OMGUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ICXUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ICPBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BLZUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GMTUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FTMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BANDUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOGEBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XRPBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XRPUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FTTUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SXPUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CRVUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BELUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOTUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '250000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XEMUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GMTBUSD',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ONEUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': '1000LUNCBUSD',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ZILUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AXSUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DYDXUSDT',
#   'positionAmt': '0.0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'OCEANUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CHZUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ANKRUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DUSKUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSDT_220624',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '375000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CTSIUSDT',
#   'positionAmt': '0',
#   'entryPrice': '0.0',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxNotionalValue': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0}]

# %%
client.futures_position_information(symbol = "BTCUSDT") # current Open Positions for one symbol
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21766.18845553',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 1655300781971}]

# %% [markdown]
# __Coin-margined Account__

# %%
client.futures_coin_account() # Account details
# Out:
# {'feeTier': 0,
#  'canTrade': True,
#  'canDeposit': True,
#  'canWithdraw': True,
#  'updateTime': 0,
#  'assets': [{'asset': 'MATIC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'BTC',
#    'walletBalance': '10.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '10.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '10.00000000',
#    'crossWalletBalance': '10.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '10.00000000'},
#   {'asset': 'NEAR',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ATOM',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ADA',
#    'walletBalance': '100000.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '100000.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '100000.00000000',
#    'crossWalletBalance': '100000.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '100000.00000000'},
#   {'asset': 'AAVE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'LINK',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ETH',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'BNB',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'CRV',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'TRX',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'AXS',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'DOT',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ROSE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'XTZ',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'EOS',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ICX',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'LTC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ALGO',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'BCH',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'RUNE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'XRP',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ETC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'FIL',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'APE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'VET',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'EGLD',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'DOGE',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'UNI',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'THETA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'XLM',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'SOL',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'LUNA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'FTM',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'SAND',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'MANA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'AVAX',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'GALA',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'ZIL',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'KNC',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'XMR',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'},
#   {'asset': 'GMT',
#    'walletBalance': '0.00000000',
#    'unrealizedProfit': '0.00000000',
#    'marginBalance': '0.00000000',
#    'maintMargin': '0.00000000',
#    'initialMargin': '0.00000000',
#    'positionInitialMargin': '0.00000000',
#    'openOrderInitialMargin': '0.00000000',
#    'maxWithdrawAmount': '0.00000000',
#    'crossWalletBalance': '0.00000000',
#    'crossUnPnl': '0.00000000',
#    'availableBalance': '0.00000000'}],
#  'positions': [{'symbol': 'GALAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '150000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'MATICUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '70000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'NEARUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ATOMUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'AAVEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BTCUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ETHUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ADAUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'LINKUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BTCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BCHUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'DOTUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ETHUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '750',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'XRPUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'LINKUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'LTCUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BNBUSD_220624',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '4000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BNBUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '4000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'CRVUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '15000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'TRXUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'AXSUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '2500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'DOTUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ADAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ROSEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '100000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'XTZUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'EOSUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ICXUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'LTCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ALGOUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '150000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BCHUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'RUNEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '2500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'XRPUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BTCUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ETHUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ETCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ADAUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'LINKUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BCHUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'DOTUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '25000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'XRPUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'LTCUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'FILUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'BNBUSD_220930',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '4000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'APEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '2000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'VETUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1500000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ZILUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'KNCUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'XMRUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '500',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'GMTUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '40000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'EGLDUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'DOGEUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '5000000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'ETCUSD_210924',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'EOSUSD_210924',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'UNIUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'THETAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '10000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'XLMUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '200000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'SOLUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'FTMUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'SANDUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '50000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'MANAUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '30000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'},
#   {'symbol': 'AVAXUSD_PERP',
#    'initialMargin': '0',
#    'maintMargin': '0',
#    'unrealizedProfit': '0.00000000',
#    'positionInitialMargin': '0',
#    'openOrderInitialMargin': '0',
#    'leverage': '20',
#    'isolated': False,
#    'positionSide': 'BOTH',
#    'entryPrice': '0.00000000',
#    'maxQty': '1000',
#    'notionalValue': '0',
#    'isolatedWallet': '0',
#    'updateTime': 0,
#    'positionAmt': '0'}]}

# %%
client.futures_coin_account_balance()  # Asset Balance details
# Out:
# [{'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'MATIC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'BTC',
#   'balance': '10.00000000',
#   'withdrawAvailable': '10.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '10.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '10.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'NEAR',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ATOM',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ADA',
#   'balance': '100000.00000000',
#   'withdrawAvailable': '100000.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '100000.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '100000.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'AAVE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'LINK',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ETH',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'BNB',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'CRV',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'TRX',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'AXS',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'DOT',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ROSE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'XTZ',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'EOS',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ICX',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'LTC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ALGO',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'BCH',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'RUNE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'XRP',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ETC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'FIL',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'APE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'VET',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'EGLD',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'DOGE',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'UNI',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'THETA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'XLM',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'SOL',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'LUNA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'FTM',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'SAND',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'MANA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'AVAX',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'GALA',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'ZIL',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'KNC',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'XMR',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'},
#  {'accountAlias': 'mYmYAuuXTiXq',
#   'asset': 'GMT',
#   'balance': '0.00000000',
#   'withdrawAvailable': '0.00000000',
#   'updateTime': 1655322734574,
#   'crossWalletBalance': '0.00000000',
#   'crossUnPnl': '0.00000000',
#   'availableBalance': '0.00000000'}]

# %%
client.futures_coin_position_information() # current Open Positions
# Out:
# [{'symbol': 'GALAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '150000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'MATICUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '70000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'NEARUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ATOMUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AAVEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETHUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ADAUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LINKUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BCHUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOTUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETHUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '750',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XRPUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LINKUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LTCUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNBUSD_220624',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '4000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNBUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '4000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'CRVUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '15000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'TRXUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AXSUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '2500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOTUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ADAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ROSEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '100000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XTZUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'EOSUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ICXUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LTCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ALGOUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '150000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BCHUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'RUNEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '2500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XRPUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETHUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ADAUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LINKUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BCHUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOTUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '25000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XRPUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'LTCUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FILUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BNBUSD_220930',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '4000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'APEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '2000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'VETUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1500000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ZILUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'KNCUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XMRUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '500',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'GMTUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '40000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'EGLDUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'DOGEUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '5000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'ETCUSD_210924',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'EOSUSD_210924',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'UNIUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'THETAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '10000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'XLMUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '200000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SOLUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'FTMUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'SANDUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '50000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'MANAUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '30000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'AVAXUSD_PERP',
#   'positionAmt': '0',
#   'entryPrice': '0.00000000',
#   'markPrice': '0.00000000',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '20',
#   'maxQty': '1000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notionalValue': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0}]

# %% [markdown]
# ## Changing Settings and Modes

# %%
client

# %% [markdown]
# __Target Leverage__

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21597.31430853',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 1655322621898},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21597.31430853',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'LONG',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21597.31430853',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'SHORT',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0}]

# %%
client.futures_change_leverage(symbol = "BTCUSDT", leverage = 5)
# Out:
# {'symbol': 'BTCUSDT', 'leverage': 5, 'maxNotionalValue': '2000000'}

# %% [markdown]
# __Margin Mode (ISOLATED vs. CROSSED)__

# %%
client.futures_change_margin_type(symbol = "BTCUSDT", marginType = "ISOLATED")
# Out:
# {'code': 200, 'msg': 'success'}

# %%
client.futures_change_margin_type(symbol = "BTCUSDT", marginType = "CROSSED")
# Out:
# {'code': 200, 'msg': 'success'}

# %% [markdown]
# __Position Mode (Hedging vs. Netting)__

# %%
client.futures_get_position_mode() # position mode ()
# Out:
# {'dualSidePosition': True}

# %%
client.futures_change_position_mode(dualSidePosition = True)
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb Cell 33' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000032?line=0'>1</a> client.futures_change_position_mode(dualSidePosition = True)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:6127, in Client.futures_change_position_mode(self, **params)
#    6121 def futures_change_position_mode(self, **params):
#    6122     """Change position mode for authenticated account
#    6123
#    6124     https://binance-docs.github.io/apidocs/futures/en/#change-position-mode-trade
#    6125
#    6126     """
# -> 6127     return self._request_futures_api('post', 'positionSide/dual', True, data=params)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:339, in Client._request_futures_api(self, method, path, signed, **kwargs)
#     336 def _request_futures_api(self, method, path, signed=False, **kwargs) -> Dict:
#     337     uri = self._create_futures_api_uri(path)
# --> 339     return self._request(method, uri, signed, True, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:315, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     312 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     314 self.response = getattr(self.session, method)(uri, **kwargs)
# --> 315 return self._handle_response(self.response)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:324, in Client._handle_response(response)
#     319 """Internal helper for handling API responses from the Binance server.
#     320 Raises the appropriate exceptions when necessary; otherwise, returns the
#     321 response.
#     322 """
#     323 if not (200 <= response.status_code < 300):
# --> 324     raise BinanceAPIException(response, response.status_code, response.text)
#     325 try:
#     326     return response.json()
#
# BinanceAPIException: APIError(code=-4059): No need to change position side.

# %% [markdown]
# ## Placing Market Orders (Part 1)

# %%
client

# %%
client.futures_position_information(symbol = "BTCUSDT") # no open position
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21625.88705358',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '5',
#   'maxNotionalValue': '2000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 1655322738409},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21625.88705358',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '5',
#   'maxNotionalValue': '2000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'LONG',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21625.88705358',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '5',
#   'maxNotionalValue': '2000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'SHORT',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0}]

# %%
client.futures_get_open_orders(symbol = "BTCUSDT") # no open orders
# Out:
# []

# %% [markdown]
# __More information on placing Orders via the Futures API:__

# %% [markdown]
# https://binance-docs.github.io/apidocs/futures/en/#new-order-trade

# %%
# client.futures_create_order()

# %% [markdown]
# __Go Long 0.01 BTCUSDT, Leverage = 10__

# %%
leverage = 10
size = 0.01

# %%
client.futures_change_leverage(symbol = "BTCUSDT", leverage = leverage)
# Out:
# {'symbol': 'BTCUSDT', 'leverage': 10, 'maxNotionalValue': '1000000'}

# %%
order_open = client.futures_create_order(symbol = "BTCUSDT", side = "BUY",
                                         type = "MARKET", quantity = size)
order_open
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb Cell 45' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000044?line=0'>1</a> order_open = client.futures_create_order(symbol = "BTCUSDT", side = "BUY",
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000044?line=1'>2</a>                                          type = "MARKET", quantity = size)
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000044?line=2'>3</a> order_open
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:5985, in Client.futures_create_order(self, **params)
#    5979 def futures_create_order(self, **params):
#    5980     """Send in a new order.
#    5981
#    5982     https://binance-docs.github.io/apidocs/futures/en/#new-order-trade
#    5983
#    5984     """
# -> 5985     return self._request_futures_api('post', 'order', True, data=params)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:339, in Client._request_futures_api(self, method, path, signed, **kwargs)
#     336 def _request_futures_api(self, method, path, signed=False, **kwargs) -> Dict:
#     337     uri = self._create_futures_api_uri(path)
# --> 339     return self._request(method, uri, signed, True, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:315, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     312 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     314 self.response = getattr(self.session, method)(uri, **kwargs)
# --> 315 return self._handle_response(self.response)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:324, in Client._handle_response(response)
#     319 """Internal helper for handling API responses from the Binance server.
#     320 Raises the appropriate exceptions when necessary; otherwise, returns the
#     321 response.
#     322 """
#     323 if not (200 <= response.status_code < 300):
# --> 324     raise BinanceAPIException(response, response.status_code, response.text)
#     325 try:
#     326     return response.json()
#
# BinanceAPIException: APIError(code=-4061): Order's position side does not match user's setting.

# %%
client.futures_get_order(symbol = "BTCUSDT", orderId = order_open["orderId"]) # check order status
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb Cell 46' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000045?line=0'>1</a> client.futures_get_order(symbol = "BTCUSDT", orderId = order_open["orderId"])
#
# NameError: name 'order_open' is not defined

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21637.78559190',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 1655322738409},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21637.78559190',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'LONG',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21637.78559190',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'SHORT',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0}]

# %%
order_close = client.futures_create_order(symbol = "BTCUSDT", side = "SELL",
                                          type = "MARKET", quantity = size, reduce_Only = True)
order_close
# Out:
# ---------------------------------------------------------------------------
# BinanceAPIException                       Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb Cell 48' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000047?line=0'>1</a> order_close = client.futures_create_order(symbol = "BTCUSDT", side = "SELL",
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000047?line=1'>2</a>                                           type = "MARKET", quantity = size, reduce_Only = True)
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000047?line=2'>3</a> order_close
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:5985, in Client.futures_create_order(self, **params)
#    5979 def futures_create_order(self, **params):
#    5980     """Send in a new order.
#    5981
#    5982     https://binance-docs.github.io/apidocs/futures/en/#new-order-trade
#    5983
#    5984     """
# -> 5985     return self._request_futures_api('post', 'order', True, data=params)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:339, in Client._request_futures_api(self, method, path, signed, **kwargs)
#     336 def _request_futures_api(self, method, path, signed=False, **kwargs) -> Dict:
#     337     uri = self._create_futures_api_uri(path)
# --> 339     return self._request(method, uri, signed, True, **kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:315, in Client._request(self, method, uri, signed, force_params, **kwargs)
#     312 kwargs = self._get_request_kwargs(method, signed, force_params, **kwargs)
#     314 self.response = getattr(self.session, method)(uri, **kwargs)
# --> 315 return self._handle_response(self.response)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/binance/client.py:324, in Client._handle_response(response)
#     319 """Internal helper for handling API responses from the Binance server.
#     320 Raises the appropriate exceptions when necessary; otherwise, returns the
#     321 response.
#     322 """
#     323 if not (200 <= response.status_code < 300):
# --> 324     raise BinanceAPIException(response, response.status_code, response.text)
#     325 try:
#     326     return response.json()
#
# BinanceAPIException: APIError(code=-4061): Order's position side does not match user's setting.

# %%
client.futures_get_order(symbol = "BTCUSDT", orderId = order_close["orderId"]) # check order status
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb Cell 49' in <cell line: 1>()
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_AL_TRAIDING/Part3_Materials/NB_02_Futures_API.ipynb#ch0000048?line=0'>1</a> client.futures_get_order(symbol = "BTCUSDT", orderId = order_close["orderId"])
#
# NameError: name 'order_close' is not defined

# %%
client.futures_position_information(symbol = "BTCUSDT")
# Out:
# [{'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21623.78953254',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'BOTH',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 1655322738409},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21623.78953254',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'LONG',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0},
#  {'symbol': 'BTCUSDT',
#   'positionAmt': '0.000',
#   'entryPrice': '0.0',
#   'markPrice': '21623.78953254',
#   'unRealizedProfit': '0.00000000',
#   'liquidationPrice': '0',
#   'leverage': '10',
#   'maxNotionalValue': '1000000',
#   'marginType': 'cross',
#   'isolatedMargin': '0.00000000',
#   'isAutoAddMargin': 'false',
#   'positionSide': 'SHORT',
#   'notional': '0',
#   'isolatedWallet': '0',
#   'updateTime': 0}]

# %% [markdown]
# ## Trade and Income History

# %%
client

# %% [markdown]
# https://binance-docs.github.io/apidocs/futures/en/#account-trade-list-user_data

# %%
client.futures_account_trades(symbol = "BTCUSDT") # get all trades in the last 7 days
# Out:
# [{'symbol': 'BTCUSDT',
#   'id': 233742379,
#   'orderId': 3047212265,
#   'side': 'BUY',
#   'price': '21543.30',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2154.33000',
#   'commission': '0.43086600',
#   'commissionAsset': 'USDT',
#   'time': 1655299435502,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': True},
#  {'symbol': 'BTCUSDT',
#   'id': 233742429,
#   'orderId': 3047212490,
#   'side': 'SELL',
#   'price': '21400',
#   'qty': '0.100',
#   'realizedPnl': '-14.33000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2140',
#   'commission': '0.85600000',
#   'commissionAsset': 'USDT',
#   'time': 1655299510856,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 233742794,
#   'orderId': 3047214348,
#   'side': 'BUY',
#   'price': '21454.80',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2145.48000',
#   'commission': '0.85819200',
#   'commissionAsset': 'USDT',
#   'time': 1655300194258,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 233742814,
#   'orderId': 3047214418,
#   'side': 'SELL',
#   'price': '21422.20',
#   'qty': '0.100',
#   'realizedPnl': '-3.26000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2142.22000',
#   'commission': '0.85688800',
#   'commissionAsset': 'USDT',
#   'time': 1655300219049,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 233743073,
#   'orderId': 3047215811,
#   'side': 'SELL',
#   'price': '21485.70',
#   'qty': '0.100',
#   'realizedPnl': '0',
#   'marginAsset': 'USDT',
#   'quoteQty': '2148.57000',
#   'commission': '0.85942800',
#   'commissionAsset': 'USDT',
#   'time': 1655300727135,
#   'positionSide': 'BOTH',
#   'buyer': False,
#   'maker': False},
#  {'symbol': 'BTCUSDT',
#   'id': 233743118,
#   'orderId': 3047215968,
#   'side': 'BUY',
#   'price': '21589.60',
#   'qty': '0.100',
#   'realizedPnl': '-10.39000000',
#   'marginAsset': 'USDT',
#   'quoteQty': '2158.96000',
#   'commission': '0.86358400',
#   'commissionAsset': 'USDT',
#   'time': 1655300781971,
#   'positionSide': 'BOTH',
#   'buyer': True,
#   'maker': False}]

# %%
df = pd.DataFrame(client.futures_account_trades(symbol = "BTCUSDT"))
df
# Out:
#     symbol         id     orderId  side     price    qty   realizedPnl  \
# 0  BTCUSDT  233742379  3047212265   BUY  21543.30  0.100             0
# 1  BTCUSDT  233742429  3047212490  SELL     21400  0.100  -14.33000000
# 2  BTCUSDT  233742794  3047214348   BUY  21454.80  0.100             0
# 3  BTCUSDT  233742814  3047214418  SELL  21422.20  0.100   -3.26000000
# 4  BTCUSDT  233743073  3047215811  SELL  21485.70  0.100             0
# 5  BTCUSDT  233743118  3047215968   BUY  21589.60  0.100  -10.39000000
#
#   marginAsset    quoteQty  commission commissionAsset           time  \
# 0        USDT  2154.33000  0.43086600            USDT  1655299435502
# 1        USDT        2140  0.85600000            USDT  1655299510856
# 2        USDT  2145.48000  0.85819200            USDT  1655300194258
# 3        USDT  2142.22000  0.85688800            USDT  1655300219049
# 4        USDT  2148.57000  0.85942800            USDT  1655300727135
# 5        USDT  2158.96000  0.86358400            USDT  1655300781971
#
#   positionSide  buyer  maker
# 0         BOTH   True   True
# 1         BOTH  False  False
# 2         BOTH   True  False
# 3         BOTH  False  False
# 4         BOTH  False  False
# 5         BOTH   True  False

# %%
df.tail(2) # two most recent trades
# Out:
#     symbol         id     orderId  side     price    qty   realizedPnl  \
# 4  BTCUSDT  233743073  3047215811  SELL  21485.70  0.100             0
# 5  BTCUSDT  233743118  3047215968   BUY  21589.60  0.100  -10.39000000
#
#   marginAsset    quoteQty  commission commissionAsset           time  \
# 4        USDT  2148.57000  0.85942800            USDT  1655300727135
# 5        USDT  2158.96000  0.86358400            USDT  1655300781971
#
#   positionSide  buyer  maker
# 4         BOTH  False  False
# 5         BOTH   True  False

# %%
client.futures_income_history(symbol = "BTCUSDT") # recent income history (7 days)
# Out:
# [{'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.43086600',
#   'asset': 'USDT',
#   'time': 1655299435000,
#   'info': '233742379',
#   'tranId': 90031233742379,
#   'tradeId': '233742379'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-14.33000000',
#   'asset': 'USDT',
#   'time': 1655299510000,
#   'info': '233742429',
#   'tranId': 90030233742429,
#   'tradeId': '233742429'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.85600000',
#   'asset': 'USDT',
#   'time': 1655299510000,
#   'info': '233742429',
#   'tranId': 90030233742429,
#   'tradeId': '233742429'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.85819200',
#   'asset': 'USDT',
#   'time': 1655300194000,
#   'info': '233742794',
#   'tranId': 90031233742794,
#   'tradeId': '233742794'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-3.26000000',
#   'asset': 'USDT',
#   'time': 1655300219000,
#   'info': '233742814',
#   'tranId': 90030233742814,
#   'tradeId': '233742814'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.85688800',
#   'asset': 'USDT',
#   'time': 1655300219000,
#   'info': '233742814',
#   'tranId': 90030233742814,
#   'tradeId': '233742814'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.85942800',
#   'asset': 'USDT',
#   'time': 1655300727000,
#   'info': '233743073',
#   'tranId': 90030233743073,
#   'tradeId': '233743073'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'REALIZED_PNL',
#   'income': '-10.39000000',
#   'asset': 'USDT',
#   'time': 1655300781000,
#   'info': '233743118',
#   'tranId': 90031233743118,
#   'tradeId': '233743118'},
#  {'symbol': 'BTCUSDT',
#   'incomeType': 'COMMISSION',
#   'income': '-0.86358400',
#   'asset': 'USDT',
#   'time': 1655300781000,
#   'info': '233743118',
#   'tranId': 90031233743118,
#   'tradeId': '233743118'}]

# %%
pd.DataFrame(client.futures_income_history(symbol = "BTCUSDT")).tail(3)
# Out:
#     symbol    incomeType        income asset           time       info  \
# 6  BTCUSDT    COMMISSION   -0.85942800  USDT  1655300727000  233743073
# 7  BTCUSDT  REALIZED_PNL  -10.39000000  USDT  1655300781000  233743118
# 8  BTCUSDT    COMMISSION   -0.86358400  USDT  1655300781000  233743118
#
#            tranId    tradeId
# 6  90030233743073  233743073
# 7  90031233743118  233743118
# 8  90031233743118  233743118

# %% [markdown]
# ## Placing Market Orders (Part 2)

# %%
client

# %% [markdown]
# __Go Short 0.01 BTCUSDT, Leverage = 15__

# %%
leverage = 15
size = 0.01

# %%
client.futures_change_leverage(symbol = "BTCUSDT", leverage = leverage)

# %%
order_open = client.futures_create_order(symbol = "BTCUSDT", side = "SELL",
                                         type = "MARKET", quantity = size)
order_open

# %%
client.futures_position_information(symbol = "BTCUSDT")

# %%
order_close = client.futures_create_order(symbol = "BTCUSDT", side = "BUY",
                                          type = "MARKET", quantity = size, reduceOnly = True)
order_close

# %%
df = pd.DataFrame(client.futures_account_trades(symbol = "BTCUSDT"))

# %%
df.tail(2)

# %% [markdown]
# ## Getting Historical Futures Market Data

# %%
from binance.client import Client
import pandas as pd

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com", testnet = True) # Testnet!!!

# %% [markdown]
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

# %% [markdown]
# __Spot__

# %%
client.get_historical_klines(symbol = "BTCUSDT", interval = "1d", 
                             start_str = "2020-01-01", end_str = None, limit = 1000)

# %% [markdown]
# __Futures__

# %%
client.futures_historical_klines(symbol = "BTCUSDT", interval = "1d",
                                 start_str = "2020-01-01", end_str = None, limit = 1000)

# %%
def get_history(symbol, interval, start, end = None):
    bars = client.futures_historical_klines(symbol = symbol, interval = interval,
                                        start_str = start, end_str = end, limit = 1000)
    df = pd.DataFrame(bars)
    df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
    df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                  "Clos Time", "Quote Asset Volume", "Number of Trades",
                  "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
    df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
    df.set_index("Date", inplace = True)
    for column in df.columns:
        df[column] = pd.to_numeric(df[column], errors = "coerce")
    
    return df

# %%
data = get_history(symbol = "BTCUSDT", interval = "1d", start = "2020-01-01")
data

# %%
data.info()

# %% [markdown]
# ## Streaming Future Prices in real-time

# %%
from binance import ThreadedWebsocketManager
import pandas as pd

# %%
df = pd.DataFrame(columns = ["Open", "High", "Low", "Close", "Volume", "Complete"])
df

# %%
def stream_candles(msg):
    ''' define how to process incoming WebSocket messages '''
    
    # extract the required items from msg
    event_time = pd.to_datetime(msg["E"], unit = "ms")
    start_time = pd.to_datetime(msg["k"]["t"], unit = "ms")
    first   = float(msg["k"]["o"])
    high    = float(msg["k"]["h"])
    low     = float(msg["k"]["l"])
    close   = float(msg["k"]["c"])
    volume  = float(msg["k"]["v"])
    complete=       msg["k"]["x"]
    
    # print out
    print("Time: {} | Price: {}".format(event_time, close))
    
    # feed df (add new bar / update latest bar)
    df.loc[start_time] = [first, high, low, close, volume, complete]

# %%
twm = ThreadedWebsocketManager(testnet = True)
twm.start()

# %% [markdown]
# valid intervals - 1m, 3m, 5m, 15m, 30m, 1h, 2h, 4h, 6h, 8h, 12h, 1d, 3d, 1w, 1M

# %% [markdown]
# __Spot__

# %%
# twm.start_kline_socket(callback = stream_candles, symbol = "BTCUSDT", interval = "1m")

# %% [markdown]
# __Futures__

# %%
twm.start_kline_futures_socket(callback = stream_candles, symbol = "BTCUSDT", interval = "1m")

# %%
twm.stop()

# %%
df

# %%
df.info()

# %% [markdown]
# ## The Futures Trader

# %%
from binance.client import Client
from binance import ThreadedWebsocketManager
import pandas as pd
import numpy as np
from datetime import datetime, timedelta
import time

# %%
class FuturesTrader(): # Triple SMA Crossover
    
    def __init__(self, symbol, bar_length, sma_s, sma_m, sma_l, units, position = 0, leverage = 5):
        
        self.symbol = symbol
        self.bar_length = bar_length
        self.available_intervals = ["1m", "3m", "5m", "15m", "30m", "1h", "2h", "4h", "6h", "8h", "12h", "1d", "3d", "1w", "1M"]
        self.units = units
        self.position = position
        self.leverage = leverage # NEW
        self.cum_profits = 0 # NEW
        #self.trades = 0 
        #self.trade_values = []
        
        #*****************add strategy-specific attributes here******************
        self.SMA_S = sma_s
        self.SMA_M = sma_m
        self.SMA_L = sma_l
        #************************************************************************
    
    def start_trading(self, historical_days):
        
        client.futures_change_leverage(symbol = "BTCUSDT", leverage = self.leverage) # NEW
        
        self.twm = ThreadedWebsocketManager(testnet = True) # testnet
        self.twm.start()
        
        if self.bar_length in self.available_intervals:
            self.get_most_recent(symbol = self.symbol, interval = self.bar_length,
                                 days = historical_days)
            self.twm.start_kline_futures_socket(callback = self.stream_candles,
                                        symbol = self.symbol, interval = self.bar_length) # Adj: start_kline_futures_socket
        # "else" to be added later in the course 
    
    def get_most_recent(self, symbol, interval, days):
    
        now = datetime.utcnow()
        past = str(now - timedelta(days = days))
    
        bars = client.futures_historical_klines(symbol = symbol, interval = interval,
                                            start_str = past, end_str = None, limit = 1000) # Adj: futures_historical_klines
        df = pd.DataFrame(bars)
        df["Date"] = pd.to_datetime(df.iloc[:,0], unit = "ms")
        df.columns = ["Open Time", "Open", "High", "Low", "Close", "Volume",
                      "Clos Time", "Quote Asset Volume", "Number of Trades",
                      "Taker Buy Base Asset Volume", "Taker Buy Quote Asset Volume", "Ignore", "Date"]
        df = df[["Date", "Open", "High", "Low", "Close", "Volume"]].copy()
        df.set_index("Date", inplace = True)
        for column in df.columns:
            df[column] = pd.to_numeric(df[column], errors = "coerce")
        df["Complete"] = [True for row in range(len(df)-1)] + [False]
        
        self.data = df
    
    def stream_candles(self, msg):
        
        # extract the required items from msg
        event_time = pd.to_datetime(msg["E"], unit = "ms")
        start_time = pd.to_datetime(msg["k"]["t"], unit = "ms")
        first   = float(msg["k"]["o"])
        high    = float(msg["k"]["h"])
        low     = float(msg["k"]["l"])
        close   = float(msg["k"]["c"])
        volume  = float(msg["k"]["v"])
        complete=       msg["k"]["x"]
        
        # print out
        print(".", end = "", flush = True) 
    
        # feed df (add new bar / update latest bar)
        self.data.loc[start_time] = [first, high, low, close, volume, complete]
        
        # prepare features and define strategy/trading positions whenever the latest bar is complete
        if complete == True:
            self.define_strategy()
            self.execute_trades()
        
    def define_strategy(self):
        
        data = self.data.copy()
        
        #******************** define your strategy here ************************
        data = data[["Close"]].copy()
        
        data["SMA_S"] = data.Close.rolling(window = self.SMA_S).mean()
        data["SMA_M"] = data.Close.rolling(window = self.SMA_M).mean()
        data["SMA_L"] = data.Close.rolling(window = self.SMA_L).mean()
        
        data.dropna(inplace = True)
                
        cond1 = (data.SMA_S > data.SMA_M) & (data.SMA_M > data.SMA_L)
        cond2 = (data.SMA_S < data.SMA_M) & (data.SMA_M < data.SMA_L)
        
        data["position"] = 0
        data.loc[cond1, "position"] = 1
        data.loc[cond2, "position"] = -1
        #***********************************************************************
        
        self.prepared_data = data.copy()
    
    def execute_trades(self): # Adj! 
        if self.prepared_data["position"].iloc[-1] == 1: # if position is long -> go/stay long
            if self.position == 0:
                order = client.futures_create_order(symbol = self.symbol, side = "BUY", type = "MARKET", quantity = self.units)
                self.report_trade("GOING LONG")  
            elif self.position == -1:
                order = client.futures_create_order(symbol = self.symbol, side = "BUY", type = "MARKET", quantity = 2 * self.units)
                self.report_trade("GOING LONG")
            self.position = 1
        elif self.prepared_data["position"].iloc[-1] == 0: # if position is neutral -> go/stay neutral
            if self.position == 1:
                order = client.futures_create_order(symbol = self.symbol, side = "SELL", type = "MARKET", quantity = self.units)
                self.report_trade("GOING NEUTRAL") 
            elif self.position == -1:
                order = client.futures_create_order(symbol = self.symbol, side = "BUY", type = "MARKET", quantity = self.units)
                self.report_trade("GOING NEUTRAL")
            self.position = 0
        if self.prepared_data["position"].iloc[-1] == -1: # if position is short -> go/stay short
            if self.position == 0:
                order = client.futures_create_order(symbol = self.symbol, side = "SELL", type = "MARKET", quantity = self.units)
                self.report_trade("GOING SHORT") 
            elif self.position == 1:
                order = client.futures_create_order(symbol = self.symbol, side = "SELL", type = "MARKET", quantity = 2 * self.units)
                self.report_trade("GOING SHORT")
            self.position = -1
    
    def report_trade(self, going): # Adj!
        
        time.sleep(0.1)
        trade = client.futures_account_trades(symbol = "BTCUSDT")[-1]
        
        # extract data from trade object
        trade_time = pd.to_datetime(trade["time"], unit = "ms")
        price = round(float(trade["price"]), 5)
        base_units = round(float(trade["qty"]), 5)
        quote_units = round(float(trade["quoteQty"]), 5)
        commission = round(-float(trade["commission"]), 5)
        real_profit = round(float(trade["realizedPnl"]), 5)
        
        # calculate cumulative trading profits
        self.cum_profits += round((commission + real_profit), 5)
        
        # print trade report
        print(2 * "\n" + 100* "-")
        print("{} | {}".format(trade_time, going)) 
        print("{} | Base_Units = {} | Quote_Units = {} | Price = {} ".format(trade_time, base_units, quote_units, price))
        print("{} | Profit = {} | CumProfits = {} ".format(trade_time, real_profit, self.cum_profits))
        print(100 * "-" + "\n")

# %%
client = Client(api_key = api_key, api_secret = secret_key, tld = "com", testnet = True)

# %%
symbol = "BTCUSDT"
bar_length = "1m"
sma_s = 10
sma_m = 20
sma_l = 50
units = 0.001
position = 0
leverage = 10

# %%
trader = FuturesTrader(symbol = symbol, bar_length = bar_length, sma_s = sma_s, sma_m = sma_m, sma_l = sma_l, 
                       units = units, position = position, leverage = leverage)

# %%
trader.start_trading(historical_days = 1/24)

# %%
trader.twm.stop()

# %%
trader.prepared_data
