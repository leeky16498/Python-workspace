# %% [markdown]
# # Creating and Backtesting MACD Strategies

# %% [markdown]
# 1. MACD는 지수이동평균보다 시장의 변동성을 더 적극적으로 반영하는 수치이다. 이동평균수렴 및 확산지수라고 부른다.
# 2. 청색선은 각 자료의 차이이며, 적색선은 9일간의 지수이동평균을 나타낸다.
# 3. 두선의 오실레이터는 0 주변에서만 극적으로 계속 움직인다.
# 4. 기본적으로 전략은 시그널 선의 교차전략이다. MACD가 MACD_signal보다 높은 지점에서는 롱, 낮은 지점에서는 숏을 간다.
# 5. 지수이동평균차에 대한 지수이동평균을 다시 구한 후 비교한다.

# %% [markdown]
# ## Getting the Data

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
plt.style.use("seaborn")

# %%
data = pd.read_csv("eurusd.csv", parse_dates = ["Date"], index_col = "Date")

# %%
data
# Out:
#                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 4275 entries, 2004-01-01 to 2020-06-30
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   price   4275 non-null   float64
# dtypes: float64(1)
# memory usage: 66.8 KB

# %%
data.plot(figsize = (12, 8), title = "EUR/USD", fontsize = 12)
plt.show()

# %% [markdown]
# ## Defining an MACD Strategy (Part 1)

# %%
data
# Out:
#                price
# Date
# 2004-01-01  1.258194
# 2004-01-02  1.258194
# 2004-01-05  1.268698
# 2004-01-06  1.272103
# 2004-01-07  1.264095
# ...              ...
# 2020-06-24  1.131235
# 2020-06-25  1.125087
# 2020-06-26  1.122208
# 2020-06-29  1.122586
# 2020-06-30  1.124720
#
# [4275 rows x 1 columns]

# %%
ema_s = 12 # EMA Short
ema_l = 26 # EMA Long

# %%
data["EMA_S"] = data.price.ewm(span = ema_s, min_periods = ema_s).mean()

# %%
data["EMA_L"] = data.price.ewm(span = ema_l, min_periods = ema_l).mean()

# %%
data
# Out:
#                price     EMA_S     EMA_L
# Date
# 2004-01-01  1.258194       NaN       NaN
# 2004-01-02  1.258194       NaN       NaN
# 2004-01-05  1.268698       NaN       NaN
# 2004-01-06  1.272103       NaN       NaN
# 2004-01-07  1.264095       NaN       NaN
# ...              ...       ...       ...
# 2020-06-24  1.131235  1.125123  1.117852
# 2020-06-25  1.125087  1.125118  1.118388
# 2020-06-26  1.122208  1.124670  1.118671
# 2020-06-29  1.122586  1.124350  1.118961
# 2020-06-30  1.124720  1.124407  1.119387
#
# [4275 rows x 3 columns]

# %%
data.loc["2016", ["price", "EMA_S", "EMA_L"]].plot(figsize = (12, 8))
plt.show()

# %%
data["MACD"] = data.EMA_S - data.EMA_L

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD
# Date
# 2004-01-01  1.258194       NaN       NaN       NaN
# 2004-01-02  1.258194       NaN       NaN       NaN
# 2004-01-05  1.268698       NaN       NaN       NaN
# 2004-01-06  1.272103       NaN       NaN       NaN
# 2004-01-07  1.264095       NaN       NaN       NaN
# ...              ...       ...       ...       ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272
# 2020-06-25  1.125087  1.125118  1.118388  0.006730
# 2020-06-26  1.122208  1.124670  1.118671  0.005999
# 2020-06-29  1.122586  1.124350  1.118961  0.005389
# 2020-06-30  1.124720  1.124407  1.119387  0.005019
#
# [4275 rows x 4 columns]

# %%
data.loc["2016", ["EMA_S", "EMA_L", "MACD"]].plot(figsize = (12, 8), secondary_y = "MACD")
plt.show()

# %%
signal_mw = 9 # Moving Window for Signal Line

# %%
data["MACD_Signal"] = data.MACD.ewm(span = signal_mw, min_periods = signal_mw).mean()

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal
# Date
# 2004-01-01  1.258194       NaN       NaN       NaN          NaN
# 2004-01-02  1.258194       NaN       NaN       NaN          NaN
# 2004-01-05  1.268698       NaN       NaN       NaN          NaN
# 2004-01-06  1.272103       NaN       NaN       NaN          NaN
# 2004-01-07  1.264095       NaN       NaN       NaN          NaN
# ...              ...       ...       ...       ...          ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272     0.008516
# 2020-06-25  1.125087  1.125118  1.118388  0.006730     0.008158
# 2020-06-26  1.122208  1.124670  1.118671  0.005999     0.007727
# 2020-06-29  1.122586  1.124350  1.118961  0.005389     0.007259
# 2020-06-30  1.124720  1.124407  1.119387  0.005019     0.006811
#
# [4275 rows x 5 columns]

# %%
data.loc["2016"]
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal
# Date
# 2016-01-01  1.085906  1.091559  1.089167  0.002392     0.002641
# 2016-01-04  1.085399  1.090611  1.088888  0.001723     0.002458
# 2016-01-05  1.082755  1.089402  1.088433  0.000969     0.002160
# 2016-01-06  1.075199  1.087217  1.087453 -0.000236     0.001681
# 2016-01-07  1.077900  1.085784  1.086745 -0.000962     0.001152
# ...              ...       ...       ...       ...          ...
# 2016-12-26  1.045478  1.049165  1.058405 -0.009240    -0.008833
# 2016-12-27  1.045697  1.048631  1.057464 -0.008832    -0.008833
# 2016-12-28  1.046233  1.048262  1.056632 -0.008370    -0.008740
# 2016-12-29  1.041699  1.047253  1.055526 -0.008273    -0.008647
# 2016-12-30  1.057530  1.048834  1.055674 -0.006840    -0.008285
#
# [261 rows x 5 columns]

# %%
data.loc["2016", ["MACD", "MACD_Signal"]].plot(figsize = (12, 8))
plt.show()

# %% [markdown]
# ## Defining an MACD Strategy (Part 2)

# %%
data["position"] = np.where(data.MACD - data.MACD_Signal > 0, 1, -1)

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal  position
# Date
# 2004-01-01  1.258194       NaN       NaN       NaN          NaN        -1
# 2004-01-02  1.258194       NaN       NaN       NaN          NaN        -1
# 2004-01-05  1.268698       NaN       NaN       NaN          NaN        -1
# 2004-01-06  1.272103       NaN       NaN       NaN          NaN        -1
# 2004-01-07  1.264095       NaN       NaN       NaN          NaN        -1
# ...              ...       ...       ...       ...          ...       ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272     0.008516        -1
# 2020-06-25  1.125087  1.125118  1.118388  0.006730     0.008158        -1
# 2020-06-26  1.122208  1.124670  1.118671  0.005999     0.007727        -1
# 2020-06-29  1.122586  1.124350  1.118961  0.005389     0.007259        -1
# 2020-06-30  1.124720  1.124407  1.119387  0.005019     0.006811        -1
#
# [4275 rows x 6 columns]

# %%
data.loc[:, ["MACD", "MACD_Signal", "position"]].plot(figsize = (12, 8), fontsize = 12, 
                                                      secondary_y = "position", title = "EUR/USD")
plt.show()

# %%
data.loc["2016", ["MACD", "MACD_Signal", "position"]].plot(figsize = (12, 8), fontsize = 12,
                                                           secondary_y = "position", title = "EUR/USD")
plt.show()

# %% [markdown]
# ## Vectorized Strategy Backtesting

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal  position  \
# Date
# 2004-02-18  1.272508  1.271449  1.266693  0.004756     0.003408         1
# 2004-02-19  1.275705  1.272106  1.267405  0.004700     0.003691         1
# 2004-02-20  1.254202  1.269345  1.266367  0.002978     0.003538        -1
# 2004-02-23  1.257197  1.267473  1.265649  0.001824     0.003175        -1
# 2004-02-24  1.267797  1.267523  1.265817  0.001706     0.002868        -1
# ...              ...       ...       ...       ...          ...       ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272     0.008516        -1
# 2020-06-25  1.125087  1.125118  1.118388  0.006730     0.008158        -1
# 2020-06-26  1.122208  1.124670  1.118671  0.005999     0.007727        -1
# 2020-06-29  1.122586  1.124350  1.118961  0.005389     0.007259        -1
# 2020-06-30  1.124720  1.124407  1.119387  0.005019     0.006811        -1
#
#              returns  strategy  trades  strategy_net  creturns  cstrategy  \
# Date
# 2004-02-18 -0.010386 -0.010386     0.0     -0.010386  0.989667   0.989667
# 2004-02-19  0.002510  0.002510     0.0      0.002510  0.992154   0.992154
# 2004-02-20 -0.017000 -0.017000     2.0     -0.017140  0.975430   0.975430
# 2004-02-23  0.002386 -0.002386     0.0     -0.002386  0.977760   0.973106
# 2004-02-24  0.008395 -0.008395     0.0     -0.008395  0.986003   0.964970
# ...              ...       ...     ...           ...       ...        ...
# 2020-06-24  0.002892 -0.002892     0.0     -0.002892  0.879795   0.436655
# 2020-06-25 -0.005449  0.005449     0.0      0.005449  0.875014   0.439041
# 2020-06-26 -0.002562  0.002562     0.0      0.002562  0.872775   0.440168
# 2020-06-29  0.000337 -0.000337     0.0     -0.000337  0.873069   0.440019
# 2020-06-30  0.001899 -0.001899     0.0     -0.001899  0.874729   0.439185
#
#             cstrategy_net
# Date
# 2004-02-18       0.989667
# 2004-02-19       0.992154
# 2004-02-20       0.975294
# 2004-02-23       0.972969
# 2004-02-24       0.964835
# ...                   ...
# 2020-06-24       0.414206
# 2020-06-25       0.416470
# 2020-06-26       0.417538
# 2020-06-29       0.417397
# 2020-06-30       0.416605
#
# [4241 rows x 13 columns]

# %%
data["returns"] = np.log(data.price.div(data.price.shift(1)))

# %%
data.dropna(inplace = True)

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal  position  \
# Date
# 2004-02-19  1.275705  1.272106  1.267405  0.004700     0.003691         1
# 2004-02-20  1.254202  1.269345  1.266367  0.002978     0.003538        -1
# 2004-02-23  1.257197  1.267473  1.265649  0.001824     0.003175        -1
# 2004-02-24  1.267797  1.267523  1.265817  0.001706     0.002868        -1
# 2004-02-25  1.249703  1.264778  1.264566  0.000213     0.002317        -1
# ...              ...       ...       ...       ...          ...       ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272     0.008516        -1
# 2020-06-25  1.125087  1.125118  1.118388  0.006730     0.008158        -1
# 2020-06-26  1.122208  1.124670  1.118671  0.005999     0.007727        -1
# 2020-06-29  1.122586  1.124350  1.118961  0.005389     0.007259        -1
# 2020-06-30  1.124720  1.124407  1.119387  0.005019     0.006811        -1
#
#              returns  strategy  trades  strategy_net  creturns  cstrategy  \
# Date
# 2004-02-19  0.002510  0.002510     0.0      0.002510  0.992154   0.992154
# 2004-02-20 -0.017000 -0.017000     2.0     -0.017140  0.975430   0.975430
# 2004-02-23  0.002386 -0.002386     0.0     -0.002386  0.977760   0.973106
# 2004-02-24  0.008395 -0.008395     0.0     -0.008395  0.986003   0.964970
# 2004-02-25 -0.014374  0.014374     0.0      0.014374  0.971932   0.978941
# ...              ...       ...     ...           ...       ...        ...
# 2020-06-24  0.002892 -0.002892     0.0     -0.002892  0.879795   0.436655
# 2020-06-25 -0.005449  0.005449     0.0      0.005449  0.875014   0.439041
# 2020-06-26 -0.002562  0.002562     0.0      0.002562  0.872775   0.440168
# 2020-06-29  0.000337 -0.000337     0.0     -0.000337  0.873069   0.440019
# 2020-06-30  0.001899 -0.001899     0.0     -0.001899  0.874729   0.439185
#
#             cstrategy_net
# Date
# 2004-02-19       0.992154
# 2004-02-20       0.975294
# 2004-02-23       0.972969
# 2004-02-24       0.964835
# 2004-02-25       0.978804
# ...                   ...
# 2020-06-24       0.414206
# 2020-06-25       0.416470
# 2020-06-26       0.417538
# 2020-06-29       0.417397
# 2020-06-30       0.416605
#
# [4240 rows x 13 columns]

# %%
data["strategy"] = data.position.shift(1) * data["returns"]

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal  position  \
# Date
# 2004-02-19  1.275705  1.272106  1.267405  0.004700     0.003691         1
# 2004-02-20  1.254202  1.269345  1.266367  0.002978     0.003538        -1
# 2004-02-23  1.257197  1.267473  1.265649  0.001824     0.003175        -1
# 2004-02-24  1.267797  1.267523  1.265817  0.001706     0.002868        -1
# 2004-02-25  1.249703  1.264778  1.264566  0.000213     0.002317        -1
# ...              ...       ...       ...       ...          ...       ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272     0.008516        -1
# 2020-06-25  1.125087  1.125118  1.118388  0.006730     0.008158        -1
# 2020-06-26  1.122208  1.124670  1.118671  0.005999     0.007727        -1
# 2020-06-29  1.122586  1.124350  1.118961  0.005389     0.007259        -1
# 2020-06-30  1.124720  1.124407  1.119387  0.005019     0.006811        -1
#
#              returns  strategy  trades  strategy_net  creturns  cstrategy  \
# Date
# 2004-02-19  0.002510       NaN     0.0      0.002510  0.992154   0.992154
# 2004-02-20 -0.017000 -0.017000     2.0     -0.017140  0.975430   0.975430
# 2004-02-23  0.002386 -0.002386     0.0     -0.002386  0.977760   0.973106
# 2004-02-24  0.008395 -0.008395     0.0     -0.008395  0.986003   0.964970
# 2004-02-25 -0.014374  0.014374     0.0      0.014374  0.971932   0.978941
# ...              ...       ...     ...           ...       ...        ...
# 2020-06-24  0.002892 -0.002892     0.0     -0.002892  0.879795   0.436655
# 2020-06-25 -0.005449  0.005449     0.0      0.005449  0.875014   0.439041
# 2020-06-26 -0.002562  0.002562     0.0      0.002562  0.872775   0.440168
# 2020-06-29  0.000337 -0.000337     0.0     -0.000337  0.873069   0.440019
# 2020-06-30  0.001899 -0.001899     0.0     -0.001899  0.874729   0.439185
#
#             cstrategy_net
# Date
# 2004-02-19       0.992154
# 2004-02-20       0.975294
# 2004-02-23       0.972969
# 2004-02-24       0.964835
# 2004-02-25       0.978804
# ...                   ...
# 2020-06-24       0.414206
# 2020-06-25       0.416470
# 2020-06-26       0.417538
# 2020-06-29       0.417397
# 2020-06-30       0.416605
#
# [4240 rows x 13 columns]

# %%
data.dropna(inplace = True)

# %%
ptc = 0.00007

# %%
data["trades"] = data.position.diff().fillna(0).abs()

# %%
data.trades.value_counts()
# Out:
# 0.0    3863
# 2.0     376
# Name: trades, dtype: int64

# %%
data["strategy_net"] = data.strategy - data.trades * ptc

# %%
data["creturns"] = data["returns"].cumsum().apply(np.exp)
data["cstrategy"] = data["strategy"].cumsum().apply(np.exp)
data["cstrategy_net"] = data["strategy_net"].cumsum().apply(np.exp)

# %%
data
# Out:
#                price     EMA_S     EMA_L      MACD  MACD_Signal  position  \
# Date
# 2004-02-20  1.254202  1.269345  1.266367  0.002978     0.003538        -1
# 2004-02-23  1.257197  1.267473  1.265649  0.001824     0.003175        -1
# 2004-02-24  1.267797  1.267523  1.265817  0.001706     0.002868        -1
# 2004-02-25  1.249703  1.264778  1.264566  0.000213     0.002317        -1
# 2004-02-26  1.244803  1.261702  1.263036 -0.001335     0.001566        -1
# ...              ...       ...       ...       ...          ...       ...
# 2020-06-24  1.131235  1.125123  1.117852  0.007272     0.008516        -1
# 2020-06-25  1.125087  1.125118  1.118388  0.006730     0.008158        -1
# 2020-06-26  1.122208  1.124670  1.118671  0.005999     0.007727        -1
# 2020-06-29  1.122586  1.124350  1.118961  0.005389     0.007259        -1
# 2020-06-30  1.124720  1.124407  1.119387  0.005019     0.006811        -1
#
#              returns  strategy  trades  strategy_net  creturns  cstrategy  \
# Date
# 2004-02-20 -0.017000 -0.017000     0.0     -0.017000  0.983144   0.983144
# 2004-02-23  0.002386 -0.002386     0.0     -0.002386  0.985492   0.980801
# 2004-02-24  0.008395 -0.008395     0.0     -0.008395  0.993800   0.972601
# 2004-02-25 -0.014374  0.014374     0.0      0.014374  0.979617   0.986682
# 2004-02-26 -0.003929  0.003929     0.0      0.003929  0.975776   0.990566
# ...              ...       ...     ...           ...       ...        ...
# 2020-06-24  0.002892 -0.002892     0.0     -0.002892  0.886752   0.440108
# 2020-06-25 -0.005449  0.005449     0.0      0.005449  0.881933   0.442513
# 2020-06-26 -0.002562  0.002562     0.0      0.002562  0.879677   0.443648
# 2020-06-29  0.000337 -0.000337     0.0     -0.000337  0.879973   0.443499
# 2020-06-30  0.001899 -0.001899     0.0     -0.001899  0.881646   0.442657
#
#             cstrategy_net
# Date
# 2004-02-20       0.983144
# 2004-02-23       0.980801
# 2004-02-24       0.972601
# 2004-02-25       0.986682
# 2004-02-26       0.990566
# ...                   ...
# 2020-06-24       0.417540
# 2020-06-25       0.419822
# 2020-06-26       0.420899
# 2020-06-29       0.420757
# 2020-06-30       0.419959
#
# [4239 rows x 13 columns]

# %%
data[["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %%
data.loc["2020", ["creturns", "cstrategy", "cstrategy_net"]].plot(figsize = (12 , 8))
plt.show()

# %% [markdown]
# ## Using the MACDBacktester Class

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn")

# %%
pd.read_csv("forex_pairs.csv")
# Out:
#             Date  AUDEUR=X  EURUSD=X  USDGBP=X
# 0     2004-01-01   0.59780  1.258194   0.56016
# 1     2004-01-02   0.60314  1.258194   0.55751
# 2     2004-01-05   0.60467  1.268698   0.55334
# 3     2004-01-06   0.60350  1.272103   0.54906
# 4     2004-01-07   0.60728  1.264095   0.55012
# ...          ...       ...       ...       ...
# 4290  2020-06-24   0.61349  1.131235   0.79841
# 4291  2020-06-25   0.60938  1.125087   0.80561
# 4292  2020-06-26   0.61373  1.122208   0.80480
# 4293  2020-06-29   0.61128  1.122586   0.81023
# 4294  2020-06-30   0.61097  1.124720   0.81231
#
# [4295 rows x 4 columns]

# %%
from MACDBacktester import MACDBacktester as MACD

# %%
ptc = 0.00007

# %%
tester = MACD("EURUSD=X", EMA_S = 12, EMA_L = 26, signal_mw = 9,
              start = "2004-01-01", end = "2020-06-30", tc = ptc)
# MACD 백테스팅 시 12, 25, 9가 가장 일반적으로 사용된다.

# %%
tester
# Out:
# MACDBacktester(symbol = EURUSD=X, MACD(12, 26, 9), start = 2004-01-01, end = 2020-06-30)

# %%
tester.data
# Out:
#                price   returns     EMA_S     EMA_L      MACD  MACD_Signal
# Date
# 2004-01-01  1.258194       NaN       NaN       NaN       NaN          NaN
# 2004-01-02  1.258194  0.000000       NaN       NaN       NaN          NaN
# 2004-01-05  1.268698  0.008313       NaN       NaN       NaN          NaN
# 2004-01-06  1.272103  0.002681       NaN       NaN       NaN          NaN
# 2004-01-07  1.264095 -0.006315       NaN       NaN       NaN          NaN
# ...              ...       ...       ...       ...       ...          ...
# 2020-06-24  1.131235  0.002892  1.125123  1.117852  0.007272     0.008516
# 2020-06-25  1.125087 -0.005449  1.125118  1.118388  0.006730     0.008158
# 2020-06-26  1.122208 -0.002562  1.124670  1.118671  0.005999     0.007727
# 2020-06-29  1.122586  0.000337  1.124350  1.118961  0.005389     0.007259
# 2020-06-30  1.124720  0.001899  1.124407  1.119387  0.005019     0.006811
#
# [4275 rows x 6 columns]

# %%
tester.test_strategy()
# Out:
# (0.416605, -0.458123)

# %%
tester.plot_results()

# %%
tester.results
# Out:
#                price   returns     EMA_S     EMA_L      MACD  MACD_Signal  \
# Date
# 2004-02-18  1.272508 -0.010386  1.271449  1.266693  0.004756     0.003408
# 2004-02-19  1.275705  0.002510  1.272106  1.267405  0.004700     0.003691
# 2004-02-20  1.254202 -0.017000  1.269345  1.266367  0.002978     0.003538
# 2004-02-23  1.257197  0.002386  1.267473  1.265649  0.001824     0.003175
# 2004-02-24  1.267797  0.008395  1.267523  1.265817  0.001706     0.002868
# ...              ...       ...       ...       ...       ...          ...
# 2020-06-24  1.131235  0.002892  1.125123  1.117852  0.007272     0.008516
# 2020-06-25  1.125087 -0.005449  1.125118  1.118388  0.006730     0.008158
# 2020-06-26  1.122208 -0.002562  1.124670  1.118671  0.005999     0.007727
# 2020-06-29  1.122586  0.000337  1.124350  1.118961  0.005389     0.007259
# 2020-06-30  1.124720  0.001899  1.124407  1.119387  0.005019     0.006811
#
#             position  strategy  trades  creturns  cstrategy
# Date
# 2004-02-18         1 -0.010386     0.0  0.989667   0.989667
# 2004-02-19         1  0.002510     0.0  0.992154   0.992154
# 2004-02-20        -1 -0.017140     2.0  0.975430   0.975294
# 2004-02-23        -1 -0.002386     0.0  0.977760   0.972969
# 2004-02-24        -1 -0.008395     0.0  0.986003   0.964835
# ...              ...       ...     ...       ...        ...
# 2020-06-24        -1 -0.002892     0.0  0.879795   0.414206
# 2020-06-25        -1  0.005449     0.0  0.875014   0.416470
# 2020-06-26        -1  0.002562     0.0  0.872775   0.417538
# 2020-06-29        -1 -0.000337     0.0  0.873069   0.417397
# 2020-06-30        -1 -0.001899     0.0  0.874729   0.416605
#
# [4241 rows x 11 columns]

# %%
tester.optimize_parameters((5, 20, 1), (21, 50, 1), (5, 20, 1))
# Out:
# (array([18., 30., 19.]), 0.760579)

# %%
tester.plot_results()
# 그럼에도 불구하고 MACD 백테스팅으로는 수익이 나지 않는 주식이다.

# %% [markdown]
# __AUD / EUR__

# %%
tester = MACD("AUDEUR=X", EMA_S = 12, EMA_L = 26, signal_mw = 9, 
              start = "2004-01-01", end = "2020-06-30", tc = 0)

# %%
tester.test_strategy()
# Out:
# (1.061038, 0.076032)

# %%
tester.plot_results()

# %%
tester.optimize_parameters((5, 20, 1), (21, 50, 1), (5, 20, 1))
# Out:
# (array([ 5., 23.,  6.]), 2.183987)

# %%
tester.plot_results()

# %% [markdown]
# __Optimization and Backtesting (2004-2014)__ ("In-Sample")

# %%
tester = MACD("AUDEUR=X", EMA_S = 12, EMA_L = 26, signal_mw = 9,
              start = "2004-01-01", end = "2014-12-31", tc = 0)

# %%
tester.optimize_parameters((5, 20, 1), (21, 50, 1), (5, 20, 1))
# Out:
# (array([ 6., 24.,  7.]), 1.56004)

# %%
tester.plot_results()

# %% [markdown]
# __Forward Testing (2015-2020)__ ("Out-Sample")

# %%
forwardtester = MACD("AUDEUR=X", EMA_S = 6, EMA_L = 24, signal_mw = 7,
                     start = "2015-01-01", end = "2020-06-30", tc = 0)

# %%
forwardtester.test_strategy()
# Out:
# (1.237419, 0.348736)

# %%
forwardtester.plot_results()

# %% [markdown]
# ## Alternative Strategies and Interpretations

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from scipy.optimize import brute
plt.style.use("seaborn")
from MACDBacktester import MACDBacktester as MACD

# %%
tester = MACD("EURUSD=X", EMA_S = 12, EMA_L = 26, signal_mw = 9,
              start = "2004-01-01", end = "2020-06-30", tc = 0)

# %%
alt = tester.data.dropna()
alt
# Out:
#                price   returns     EMA_S     EMA_L      MACD  MACD_Signal
# Date
# 2004-02-17  1.285793  0.007251  1.271256  1.266191  0.005065     0.003018
# 2004-02-18  1.272508 -0.010386  1.271449  1.266693  0.004756     0.003408
# 2004-02-19  1.275705  0.002510  1.272106  1.267405  0.004700     0.003691
# 2004-02-20  1.254202 -0.017000  1.269345  1.266367  0.002978     0.003538
# 2004-02-23  1.257197  0.002386  1.267473  1.265649  0.001824     0.003175
# ...              ...       ...       ...       ...       ...          ...
# 2020-06-24  1.131235  0.002892  1.125123  1.117852  0.007272     0.008516
# 2020-06-25  1.125087 -0.005449  1.125118  1.118388  0.006730     0.008158
# 2020-06-26  1.122208 -0.002562  1.124670  1.118671  0.005999     0.007727
# 2020-06-29  1.122586  0.000337  1.124350  1.118961  0.005389     0.007259
# 2020-06-30  1.124720  0.001899  1.124407  1.119387  0.005019     0.006811
#
# [4242 rows x 6 columns]

# %% [markdown]
# __Main Strategy: MACD Signal Line Crossover__

# %%
alt.loc["2016", ["MACD", "MACD_Signal"]].plot(figsize = (12, 8))
#plt.hlines(y = 0, xmin = alt.index[0], xmax = alt.index[-1], color = "r", label = "Zero")
plt.title("Signal Line Crossover", fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# __Alternative 1: Zero Crossover__

# %%
alt.loc["2016", "MACD"].plot(figsize = (12, 8))
plt.hlines(y = 0, xmin = alt.index[0], xmax = alt.index[-1], color = "r", label = "Zero")
plt.title("Zero Crossover", fontsize = 15)
plt.legend()
plt.show()

# %% [markdown]
# __Alternative 2: Divergence__

# %% [markdown]
# Convergence:
# - if __Price__ reaches __higher highs__ -> __MACD__ reaches __higher highs__ (confirmation)
# - if __Price__ reaches __lower lows__ -> __MACD__ reaches __lower lows__ (confirmation)

# %%
alt.loc["03-2013":"06-2013", ["price", "MACD"]].plot(figsize = (12, 8), secondary_y = "MACD")
plt.show()

# %% [markdown]
# Divergence:
# - if __Price__ reaches __higher highs__ -> __MACD fails__ to reach higher highs (__Bearish Divergence__)
# - if __Price__ reaches __lower lows__ -> __MACD fails__ to reach lower lows (__Bullish Divergence__)

# %%
alt.loc["03-2016":"06-2016", ["price", "MACD"]].plot(figsize = (12, 8), secondary_y = "MACD")
plt.title("Bearish Divergence", fontsize = 15)
plt.show()

# %%
alt.loc["05-2012":"11-2012", ["price", "MACD"]].plot(figsize = (12, 8), secondary_y = "MACD")
plt.title("Bullish Divergence", fontsize = 15)
plt.show()
