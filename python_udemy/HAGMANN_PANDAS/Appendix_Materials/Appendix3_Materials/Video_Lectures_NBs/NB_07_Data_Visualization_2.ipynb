# %% [markdown]
# # Appendix 3: Python Libraries Crash Course

# %% [markdown]
# ## Part 7: Data Visualization with Seaborn

# %% [markdown]
# ## First Steps

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
plt.figure(figsize=(12, 8))
sns.countplot(data = titanic, x = "sex")
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=2, palette= "viridis")
sns.countplot(data = titanic, x = "sex", hue = "pclass") 
#hue파라미터에 추가적으로 분류하기 위한 데이터를 넣어줌으로서 원하는 히스토그램을 분류해내어 그릴 수 있다.
plt.show()

# %% [markdown]
# ## Categorical Plots

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.stripplot(data = titanic, x = "sex", y = "age", jitter = True, hue = "pclass", dodge = True)
plt.show()
# 스트립플롯 : jitter를 true로 하면, 점들을 겹쳐지지 않게 설정할 수 있다.
# hue : 를 사용하면 원하는 분류에 따라서 그래프를 분류하여 그려줄 수 있다.
# dodge : 를 사용하면 hue를 통해서 분류한 그래프를 각자 분류해줄 수 있다.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.swarmplot(data = titanic, x = "sex", y = "age", hue = "pclass", dodge = True)
plt.show()
# swarmplot은 데이터들이 겹치지 않는 플롯을 그려낸다.

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data = titanic, x = "sex", y = "age", hue = "pclass", dodge = True)
sns.swarmplot(data = titanic, x = "sex", y = "age", hue = "pclass", dodge = True, color = "black")
plt.show()
# 두개를 결합해서 이렇게 그려줄 수도 있다.
# Out:
# /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/categorical.py:1296: UserWarning: 5.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.violinplot(data = titanic, x = "pclass", y = "age", hue = "sex", dodge = True, split = True )
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.barplot(data = titanic, x = "pclass", y = "age", hue = "sex", dodge = True)
plt.show()

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.5)
sns.pointplot(data = titanic, x = "pclass", y = "age", hue = "sex", dodge = True)
plt.show()

# %% [markdown]
# ## Jointplots / Regression

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
sns.set(font_scale=1.5)
sns.jointplot(data = titanic, x = "age", y = "fare", height = 8, kind = "reg")
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x = "age", y = "fare", aspect= 1, height=8,  col = "sex")
#col = 따로 그려준다, hue = 하나의 그래프에 겹쳐서 그려준다.
plt.show()

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x = "age", y = "survived", aspect= 1, height=8, col = "sex", logistic= True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb Cell 24' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb#ch0000022?line=0'>1</a> sns.set(font_scale=1.5)
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb#ch0000022?line=1'>2</a> sns.lmplot(data = titanic, x = "age", y = "survived", aspect= 1, height=8, col = "sex", logistic= True)
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb#ch0000022?line=2'>3</a> plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:645, in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     636 # Draw the regression plot on each facet
#     637 regplot_kws = dict(
#     638     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
#     639     scatter=scatter, fit_reg=fit_reg, ci=ci, n_boot=n_boot, units=units,
#    (...)
#     643     scatter_kws=scatter_kws, line_kws=line_kws,
#     644 )
# --> 645 facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     646 facets.set_axis_labels(x, y)
#     648 # Add a legend
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:777, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     774     kwargs["data"] = data_ijk
#     776     # Draw the plot
# --> 777     self._facet_plot(func, ax, args, kwargs)
#     779 # For axis labels, prefer to use positional args for backcompat
#     780 # but also extract the x/y kwargs and use if no corresponding arg
#     781 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:806, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804     plot_args = []
#     805     plot_kwargs["ax"] = ax
# --> 806 func(*plot_args, **plot_kwargs)
#     808 # Sort out the supporting information
#     809 self._update_legend_data(ax)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:208, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     206     yhat, yhat_boots = self.fit_poly(grid, self.order)
#     207 elif self.logistic:
# --> 208     from statsmodels.genmod.generalized_linear_model import GLM
#     209     from statsmodels.genmod.families import Binomial
#     210     yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
#     211                                             family=Binomial())
#
# ModuleNotFoundError: No module named 'statsmodels'

# %%
sns.set(font_scale=1.5)
sns.lmplot(data = titanic, x = "age", y = "survived", aspect= 1, height=8, col = "pclass", logistic = True)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# /Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb Cell 25' in <cell line: 2>()
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb#ch0000023?line=0'>1</a> sns.set(font_scale=1.5)
# ----> <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb#ch0000023?line=1'>2</a> sns.lmplot(data = titanic, x = "age", y = "survived", aspect= 1, height=8, col = "pclass", logistic= True)
#       <a href='vscode-notebook-cell:/Users/kyungyunlee/Desktop/PYTHON/PYTHON_UDEMY/HAGMANN_PANDAS/Appendix_Materials/Appendix3_Materials/Video_Lectures_NBs/NB_07_Data_Visualization_2.ipynb#ch0000023?line=2'>3</a> plt.show()
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:645, in lmplot(x, y, data, hue, col, row, palette, col_wrap, height, aspect, markers, sharex, sharey, hue_order, col_order, row_order, legend, legend_out, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, x_jitter, y_jitter, scatter_kws, line_kws, facet_kws, size)
#     636 # Draw the regression plot on each facet
#     637 regplot_kws = dict(
#     638     x_estimator=x_estimator, x_bins=x_bins, x_ci=x_ci,
#     639     scatter=scatter, fit_reg=fit_reg, ci=ci, n_boot=n_boot, units=units,
#    (...)
#     643     scatter_kws=scatter_kws, line_kws=line_kws,
#     644 )
# --> 645 facets.map_dataframe(regplot, x=x, y=y, **regplot_kws)
#     646 facets.set_axis_labels(x, y)
#     648 # Add a legend
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:777, in FacetGrid.map_dataframe(self, func, *args, **kwargs)
#     774     kwargs["data"] = data_ijk
#     776     # Draw the plot
# --> 777     self._facet_plot(func, ax, args, kwargs)
#     779 # For axis labels, prefer to use positional args for backcompat
#     780 # but also extract the x/y kwargs and use if no corresponding arg
#     781 axis_labels = [kwargs.get("x", None), kwargs.get("y", None)]
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/axisgrid.py:806, in FacetGrid._facet_plot(self, func, ax, plot_args, plot_kwargs)
#     804     plot_args = []
#     805     plot_kwargs["ax"] = ax
# --> 806 func(*plot_args, **plot_kwargs)
#     808 # Sort out the supporting information
#     809 self._update_legend_data(ax)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/_decorators.py:46, in _deprecate_positional_args.<locals>.inner_f(*args, **kwargs)
#      36     warnings.warn(
#      37         "Pass the following variable{} as {}keyword arg{}: {}. "
#      38         "From version 0.12, the only valid positional argument "
#    (...)
#      43         FutureWarning
#      44     )
#      45 kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46 return f(**kwargs)
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:863, in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861 scatter_kws["marker"] = marker
#     862 line_kws = {} if line_kws is None else copy.copy(line_kws)
# --> 863 plotter.plot(ax, scatter_kws, line_kws)
#     864 return ax
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:370, in _RegressionPlotter.plot(self, ax, scatter_kws, line_kws)
#     367     self.scatterplot(ax, scatter_kws)
#     369 if self.fit_reg:
# --> 370     self.lineplot(ax, line_kws)
#     372 # Label the axes
#     373 if hasattr(self.x, "name"):
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:413, in _RegressionPlotter.lineplot(self, ax, kws)
#     411 """Draw the model."""
#     412 # Fit the regression model
# --> 413 grid, yhat, err_bands = self.fit_regression(ax)
#     414 edges = grid[0], grid[-1]
#     416 # Get set default aesthetics
#
# File /Library/Frameworks/Python.framework/Versions/3.10/lib/python3.10/site-packages/seaborn/regression.py:208, in _RegressionPlotter.fit_regression(self, ax, x_range, grid)
#     206     yhat, yhat_boots = self.fit_poly(grid, self.order)
#     207 elif self.logistic:
# --> 208     from statsmodels.genmod.generalized_linear_model import GLM
#     209     from statsmodels.genmod.families import Binomial
#     210     yhat, yhat_boots = self.fit_statsmodels(grid, GLM,
#     211                                             family=Binomial())
#
# ModuleNotFoundError: No module named 'statsmodels'

# %% [markdown]
# ## Matrixplots / Heatmaps

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# %%
titanic = pd.read_csv("titanic.csv")

# %%
titanic.head()
# Out:
#    survived  pclass     sex   age  sibsp  parch     fare embarked deck
# 0         0       3    male  22.0      1      0   7.2500        S  NaN
# 1         1       1  female  38.0      1      0  71.2833        C    C
# 2         1       3  female  26.0      0      0   7.9250        S  NaN
# 3         1       1  female  35.0      1      0  53.1000        S    C
# 4         0       3    male  35.0      0      0   8.0500        S  NaN

# %%
pd.crosstab(titanic.sex, titanic.pclass)
# Out:
# pclass    1    2    3
# sex
# female   94   76  144
# male    122  108  347

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(pd.crosstab(titanic.sex, titanic.pclass), annot= True, fmt = "d", cmap = "Reds", vmax = 150)
# annot을 true주면 히트맵 지수가 표시된다, cmap = 컬러맵 색상을 정한다, vmax는 컬러의 지수 최대치를 지정한다.
plt.show()

# %%
pd.crosstab(titanic.sex, titanic.pclass, values= titanic.survived, aggfunc= "mean")
# Out:
# pclass         1         2         3
# sex
# female  0.968085  0.921053  0.500000
# male    0.368852  0.157407  0.135447

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(pd.crosstab(titanic.sex, titanic.pclass, values= titanic.survived, aggfunc= "mean"), annot= True, cmap = "Reds")
plt.show()

# %%
titanic.corr()
#이는 상관관계 매트릭스이다. -는 음관계, +는 양관계이다.
# Out:
#           survived    pclass       age     sibsp     parch      fare
# survived  1.000000 -0.338481 -0.077221 -0.035322  0.081629  0.257307
# pclass   -0.338481  1.000000 -0.369226  0.083081  0.018443 -0.549500
# age      -0.077221 -0.369226  1.000000 -0.308247 -0.189119  0.096067
# sibsp    -0.035322  0.083081 -0.308247  1.000000  0.414838  0.159651
# parch     0.081629  0.018443 -0.189119  0.414838  1.000000  0.216225
# fare      0.257307 -0.549500  0.096067  0.159651  0.216225  1.000000

# %%
plt.figure(figsize=(12,8))
sns.set(font_scale=1.4)
sns.heatmap(titanic.corr(), annot= True, cmap = "Reds")
plt.show()
